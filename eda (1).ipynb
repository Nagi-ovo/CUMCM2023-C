# %%
# !pip install -U ydata-profiling
# !pip install --upgrade jupyter ipywidgets
# !pip install openpyxl
# Out:
# Looking in indexes: https://mirror.baidu.com/pypi/simple/, https://mirrors.aliyun.com/pypi/simple/, https://pypi.tuna.tsinghua.edu.cn/simple/
# Collecting ydata-profiling
#   Downloading https://mirrors.aliyun.com/pypi/packages/09/98/5a5fbfd48bf23acd3ceed5114d073b877965816304078151fefbf86d8458/ydata_profiling-4.5.1-py2.py3-none-any.whl (357 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.3/357.3 kB 3.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: scipy<1.12,>=1.4.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ydata-profiling) (1.11.1)
# Requirement already satisfied: pandas!=1.4.0,<2.1,>1.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ydata-profiling) (2.0.3)
# Requirement already satisfied: matplotlib<4,>=3.2 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ydata-profiling) (3.7.2)
# Collecting pydantic<2,>=1.8.1 (from ydata-profiling)
#   Downloading https://mirrors.aliyun.com/pypi/packages/bc/e0/0371e9b6c910afe502e5fe18cc94562bfd9399617c7b4f5b6e13c29115b3/pydantic-1.10.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 9.6 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ydata-profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ydata-profiling) (3.1.2)
# Collecting visions[type_image_path]==0.7.5 (from ydata-profiling)
#   Downloading https://mirrors.aliyun.com/pypi/packages/62/fa/6a8539c83d2ccbd08d5f0c843b1784af9ff514e77f4c9d5d6800fdd340f6/visions-0.7.5-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 12.1 MB/s eta 0:00:00
# Collecting numpy<1.24,>=1.16.0 (from ydata-profiling)
#   Downloading https://mirrors.aliyun.com/pypi/packages/e4/f3/679b3a042a127de0d7c84874913c3e23bb84646eb3bc6ecab3f8c872edc9/numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 12.2 MB/s eta 0:00:0000:0100:01
# Collecting htmlmin==0.1.12 (from ydata-profiling)
#   Downloading https://mirrors.aliyun.com/pypi/packages/b3/e7/fcd59e12169de19f0131ff2812077f964c6b960e7c09804d30a7bf2ab461/htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling)
#   Downloading https://mirrors.aliyun.com/pypi/packages/5b/75/76e14c8c674b0bb8f08aa6a08578474a968999e0ce1bb6c5da224ef17294/phik-0.12.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (679 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 15.2 MB/s eta 0:00:0000:01
# Requirement already satisfied: requests<3,>=2.24.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ydata-profiling) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ydata-profiling) (4.65.0)
# Collecting seaborn<0.13,>=0.10.1 (from ydata-profiling)
#   Downloading https://mirrors.aliyun.com/pypi/packages/8f/2e/17bbb83fbf102687bb2aa3d808add39da820a7698159302a1a69bb82e01c/seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 21.9 MB/s eta 0:00:00
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading https://mirrors.aliyun.com/pypi/packages/21/91/01ec16d3d0cadb499b83e6f6435c63e43f3c122c146d82a4eb9575169817/multimethod-1.9.1-py3-none-any.whl (10 kB)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling)
#   Downloading https://mirrors.aliyun.com/pypi/packages/d5/22/62831c11096ef030e35424326716d47d65d5f7eb323966c9e4725324770d/statsmodels-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 14.2 MB/s eta 0:00:0000:010:01
# Collecting typeguard<3,>=2.13.2 (from ydata-profiling)
#   Downloading https://mirrors.aliyun.com/pypi/packages/9a/bb/d43e5c75054e53efce310e79d63df0ac3f25e34c926be5dffb7d283fb2a8/typeguard-2.13.3-py3-none-any.whl (17 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling)
#   Downloading https://mirrors.aliyun.com/pypi/packages/2d/b4/19a746a986c6e38595fa5947c028b1b8e287773dcad766e648897ad2a4cf/ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 24.9 MB/s eta 0:00:00
# Collecting wordcloud>=1.9.1 (from ydata-profiling)
#   Downloading https://mirrors.aliyun.com/pypi/packages/22/0d/bb4eccd60d272b33cbc79c661c60acc604f1688cfc922deb9d3eb5be640a/wordcloud-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (455 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.4/455.4 kB 24.1 MB/s eta 0:00:00
# Collecting dacite>=1.8 (from ydata-profiling)
#   Downloading https://mirrors.aliyun.com/pypi/packages/21/0f/cf0943f4f55f0fbc7c6bd60caf1343061dff818b02af5a0d444e473bb78d/dacite-1.8.1-py3-none-any.whl (14 kB)
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling)
#   Downloading https://mirrors.aliyun.com/pypi/packages/3e/fc/651024e8b6e69bef6def2cbe27d520309f4ffc56b8d4885ab7046e1edc6c/PyWavelets-1.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 12.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pillow in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from imagehash==4.3.1->ydata-profiling) (10.0.0)
# Requirement already satisfied: attrs>=19.3.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling) (23.1.0)
# Collecting networkx>=2.4 (from visions[type_image_path]==0.7.5->ydata-profiling)
#   Downloading https://mirrors.aliyun.com/pypi/packages/a8/05/9d4f9b78ead6b2661d6e8ea772e111fc4a9fbd866ad0c81906c11206b55e/networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 15.7 MB/s eta 0:00:00a 0:00:01
# Collecting tangled-up-in-unicode>=0.0.4 (from visions[type_image_path]==0.7.5->ydata-profiling)
#   Downloading https://mirrors.aliyun.com/pypi/packages/dd/60/3651960b74aead282ec1ad819e70bdccf3ee73322d13d4339a6e3f5b7ed3/tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 15.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from matplotlib<4,>=3.2->ydata-profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from pandas!=1.4.0,<2.1,>1.1->ydata-profiling) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from pandas!=1.4.0,<2.1,>1.1->ydata-profiling) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from pydantic<2,>=1.8.1->ydata-profiling) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2023.5.7)
# Collecting patsy>=0.5.2 (from statsmodels<1,>=0.13.2->ydata-profiling)
#   Downloading https://mirrors.aliyun.com/pypi/packages/2a/e4/b3263b0e353f2be7b14f044d57874490c9cef1798a435f038683acea5c98/patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 27.0 MB/s eta 0:00:00
# Requirement already satisfied: six in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=9b3962f7698a0349a32f34c711e197d563ece6a1c5d17eb47fe319cc5b61e707
#   Stored in directory: /home/aistudio/.cache/pip/wheels/2b/64/ef/ace571c06bd90457a0dd890ba93fdafce5a1239551db4e6230
# Successfully built htmlmin
# Installing collected packages: htmlmin, typeguard, tangled-up-in-unicode, pydantic, numpy, networkx, multimethod, dacite, PyWavelets, patsy, visions, statsmodels, imagehash, wordcloud, seaborn, phik, ydata-profiling
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.0.3
#     Uninstalling pydantic-2.0.3:
#       Successfully uninstalled pydantic-2.0.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.1
#     Uninstalling numpy-1.25.1:
#       Successfully uninstalled numpy-1.25.1
# Successfully installed PyWavelets-1.4.1 dacite-1.8.1 htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.9.1 networkx-3.1 numpy-1.23.5 patsy-0.5.3 phik-0.12.3 pydantic-1.10.12 seaborn-0.12.2 statsmodels-0.14.0 tangled-up-in-unicode-0.2.0 typeguard-2.13.3 visions-0.7.5 wordcloud-1.9.2 ydata-profiling-4.5.1
# Looking in indexes: https://mirror.baidu.com/pypi/simple/, https://mirrors.aliyun.com/pypi/simple/, https://pypi.tuna.tsinghua.edu.cn/simple/
# Collecting jupyter
#   Downloading https://mirrors.aliyun.com/pypi/packages/83/df/0f5dd132200728a86190397e1ea87cd76244e42d39ec5e88efd25b2abd7e/jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting ipywidgets
#   Downloading https://mirrors.aliyun.com/pypi/packages/b8/d4/ce436660098b2f456e2b8fdf76d4f33cbc3766c874c4aa2f772c7a5e943f/ipywidgets-8.1.0-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 5.8 MB/s eta 0:00:00
# Collecting notebook (from jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/79/97/b803f9686fe25b40c8eca2d1ba440b2f878f23b87765d18fe93dd323f0b7/notebook-7.0.3-py3-none-any.whl (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 19.8 MB/s eta 0:00:0000:0100:01
# Collecting qtconsole (from jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/24/e2/7f22137bbb7270b016f6b0efa55d7598fef6ef354ba77515956bb28e8e54/qtconsole-5.4.4-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 20.0 MB/s eta 0:00:00
# Collecting jupyter-console (from jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/ca/77/71d78d58f15c22db16328a476426f7ac4a60d3a5a7ba3b9627ee2f7903d4/jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Collecting nbconvert (from jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/a4/a6/072b6fd04616f1409f37ef5967ea5bbbeea1447d4494c2d98658a95fc985/nbconvert-7.8.0-py3-none-any.whl (254 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.9/254.9 kB 29.8 MB/s eta 0:00:00
# Requirement already satisfied: ipykernel in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from jupyter) (6.24.0)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ipywidgets) (0.1.3)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ipywidgets) (8.14.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ipywidgets) (5.9.0)
# Collecting widgetsnbextension~=4.0.7 (from ipywidgets)
#   Downloading https://mirrors.aliyun.com/pypi/packages/8e/d4/d31b12ac0b87e8cc9fdb6ea1eb6596de405eaaa2f25606aaa755d0eebbc0/widgetsnbextension-4.0.8-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 22.7 MB/s eta 0:00:00a 0:00:01
# Collecting jupyterlab-widgets~=3.0.7 (from ipywidgets)
#   Downloading https://mirrors.aliyun.com/pypi/packages/74/5e/2475ac62faf2e342b2bf20b8d8e375f49400ecb38f52e4e0a7557eb1cedb/jupyterlab_widgets-3.0.8-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.0/215.0 kB 33.5 MB/s eta 0:00:00
# Requirement already satisfied: backcall in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pickleshare in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ipykernel->jupyter) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ipykernel->jupyter) (8.3.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ipykernel->jupyter) (5.3.1)
# Requirement already satisfied: nest-asyncio in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ipykernel->jupyter) (1.5.6)
# Requirement already satisfied: packaging in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ipykernel->jupyter) (23.1)
# Requirement already satisfied: psutil in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ipykernel->jupyter) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ipykernel->jupyter) (25.1.0)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from ipykernel->jupyter) (6.3.2)
# Collecting beautifulsoup4 (from nbconvert->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/57/f4/a69c20ee4f660081a7dedb1ac57f29be9378e04edfcb90c526b923d4bebc/beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 26.2 MB/s eta 0:00:00
# Collecting bleach!=5.0.0 (from nbconvert->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/ac/e2/dfcab68c9b2e7800c8f06b85c76e5f978d05b195a958daa9b1dda54a1db6/bleach-6.0.0-py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.5/162.5 kB 30.0 MB/s eta 0:00:00
# Collecting defusedxml (from nbconvert->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/07/6c/aa3f2f849e01cb6a001cd8554a88d4c77c5c1a31c95bdf1cf9301e6d9ef4/defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: jinja2>=3.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from nbconvert->jupyter) (3.1.2)
# Collecting jupyterlab-pygments (from nbconvert->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/c0/7e/c3d1df3ae9b41686e664051daedbd70eea2e1d2bd9d9c33e7e1455bc9f96/jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: markupsafe>=2.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from nbconvert->jupyter) (2.1.3)
# Collecting mistune<4,>=2.0.3 (from nbconvert->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/cc/c0/ac9587149e37cde62ae338e9db8241ae2fdc79a84bde8c8ba7caea2c22d8/mistune-3.0.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 10.1 MB/s eta 0:00:00
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/ac/5a/d670ca51e6c3d98574b9647599821590efcd811d71f58e9c89fc59a17685/nbclient-0.8.0-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 11.0 MB/s eta 0:00:00
# Collecting nbformat>=5.7 (from nbconvert->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/f4/e7/ef30a90b70eba39e675689b9eaaa92530a71d7435ab8f9cae520814e0caf/nbformat-5.9.2-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.6/77.6 kB 11.8 MB/s eta 0:00:00
# Collecting pandocfilters>=1.4.1 (from nbconvert->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/5e/a8/878258cffd53202a6cc1903c226cf09e58ae3df6b09f8ddfa98033286637/pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting tinycss2 (from nbconvert->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/da/99/fd23634d6962c2791fb8cb6ccae1f05dcbfc39bce36bba8b1c9a8d92eae8/tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Collecting jupyter-server<3,>=2.4.0 (from notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/96/a2/b432812537beaf22a9dbc0d50cb62471e57ef90df42738675760fb3dce98/jupyter_server-2.7.3-py3-none-any.whl (375 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.6/375.6 kB 35.0 MB/s eta 0:00:00
# Collecting jupyterlab-server<3,>=2.22.1 (from notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/a7/0d/6d4eab0391bd4df1c43f308368d5e177b0fa8ac632267222a23b71317091/jupyterlab_server-2.24.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 11.3 MB/s eta 0:00:00
# Collecting jupyterlab<5,>=4.0.2 (from notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/71/a3/38b9d6492a393dcfdae9e82021655432a9fd6e8f4c03c30a7b55036c0d70/jupyterlab-4.0.5-py3-none-any.whl (9.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 20.4 MB/s eta 0:00:0000:0100:01
# Collecting notebook-shim<0.3,>=0.2 (from notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/f4/79/73250372e5bbab63018b41b02d5cc6b395655ec6c1254e477ef7c913aada/notebook_shim-0.2.3-py3-none-any.whl (13 kB)
# Collecting ipython-genutils (from qtconsole->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/fa/bc/9bd3b5c2b4774d5f33b2d544f1460be9df7df2fe42f352135381c347c69a/ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting qtpy>=2.4.0 (from qtconsole->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/be/a1/13bdd2f6237379744c52cec33d417a5819a07455d880e3c5f517c13a0f21/QtPy-2.4.0-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.4/93.4 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.9.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (1.16.0)
# Collecting webencodings (from bleach!=5.0.0->nbconvert->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/f4/24/2a3e3df732393fed8b3ebf2ec078f05546de641fe1b667ee316ec1dcf3b7/webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (3.9.1)
# Requirement already satisfied: anyio>=3.1.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (3.7.1)
# Collecting argon2-cffi (from jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/a4/6a/e8a041599e78b6b3752da48000b14c8d1e8a04ded09c88c714ba047f34f5/argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Collecting jupyter-events>=0.6.0 (from jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/15/0d/3c67f6c432d8085a3cee250e1e235f27b764be90cc2d16fdcc0b1cee9572/jupyter_events-0.7.0-py3-none-any.whl (18 kB)
# Collecting jupyter-server-terminals (from jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/ea/7f/36db12bdb90f5237766dcbf59892198daab7260acbcf03fc75e2a2a82672/jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# Collecting overrides (from jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/da/28/3fa6ef8297302fc7b3844980b6c5dbc71cdbd4b61e9b2591234214d5ab39/overrides-7.4.0-py3-none-any.whl (17 kB)
# Collecting prometheus-client (from jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/ad/b3/6e18c89bf6bd120590ea538a62cae16dc763ff2745b18377c4be5495c4aa/prometheus_client-0.17.1-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 11.8 MB/s eta 0:00:00
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/a9/78/e4df1e080ed790acf3a704edf521006dd96b9841bd2e2a462c0d255e0565/Send2Trash-1.8.2-py3-none-any.whl (18 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/84/a7/c7628d79651b8c8c775d27b374315a825141b5783512e82026fb210dd639/terminado-0.17.1-py3-none-any.whl (17 kB)
# Collecting websocket-client (from jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/4b/4a/3176388095e5bae6e6a1fbee66c438809230ae0196e7de4af12c5e75c509/websocket_client-1.6.2-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 11.9 MB/s eta 0:00:00
# Collecting async-lru>=1.0.0 (from jupyterlab<5,>=4.0.2->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/fa/9f/3c3503693386c4b0f245eaf5ca6198e3b28879ca0a40bde6b0e319793453/async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<5,>=4.0.2->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/8f/b6/a1571e48550855a79898f851f57e5858b00eb36b09ea3b1a8bb65c53a290/jupyter_lsp-2.2.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.0/66.0 kB 13.6 MB/s eta 0:00:00
# Collecting tomli (from jupyterlab<5,>=4.0.2->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/97/75/10a9ebee3fd790d20926a90a2547f0bf78f371b2f13aa822c759680ca7b9/tomli-2.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: babel>=2.10 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.12.1)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.22.1->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/70/ba/fa37123a86ae8287d6678535a944f9c3377d8165e536310ed6f6cb0f0c0e/json5-0.9.14-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: jsonschema>=4.17.3 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (4.18.4)
# Requirement already satisfied: requests>=2.28 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.31.0)
# Collecting fastjsonschema (from nbformat>=5.7->nbconvert->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/9d/93/a3ca3cdeb84065d7d8f8df4cb09ab44405f109183c1d2b915ec17574e6b1/fastjsonschema-2.18.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/4c/f3/038b302fdfbe3be7da016777069f26ceefe11a681055ea1f7817546508e3/soupsieve-2.5-py3-none-any.whl (36 kB)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: pure-eval in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: idna>=2.8 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.1.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from async-lru>=1.0.0->jupyterlab<5,>=4.0.2->notebook->jupyter) (4.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.30.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.9.2)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/35/a6/145655273568ee78a581e734cf35beb9e33a370b29c5d3c8fee3744de29f/python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: pyyaml>=5.3 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (6.0.1)
# Collecting rfc3339-validator (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/7b/44/4e421b96b67b2daff264473f7465db72fbdf36a07e05494f50300cc7b0c6/rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/9e/51/17023c0f8f1869d8806b979a2bffa3f861f26a3f1a66b094288323fba52f/rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/python35-paddle120-env/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2023.5.7)
# Collecting argon2-cffi-bindings (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/ec/f7/378254e6dd7ae6f31fe40c8649eea7d4832a42243acaf0f1fff9083b2bed/argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 10.1 MB/s eta 0:00:00
# Collecting fqdn (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/cf/58/8acf1b3e91c58313ce5cb67df61001fc9dcd21be4fadb76c1a2d540e09ed/fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/7b/55/e5326141505c5d5e34c5e0935d2908a74e4561eca44108fbfb9c13d2911a/isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting jsonpointer>1.13 (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/12/f6/0232cc0c617e195f06f810534d00b74d2f348fe71b2118009ad8ad31f878/jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Collecting uri-template (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/e7/00/3fca040d7cf8a32776d3d81a00c8ee7457e00f80c649f1e4a863c8321ae9/uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting webcolors>=1.11 (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/d5/e1/3e9013159b4cbb71df9bd7611cbf90dc2c621c8aeeb677fc41dad72f2261/webcolors-1.13-py3-none-any.whl (14 kB)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/88/89/c34caf63029fb7628ec2ebd5c88ae0c9bd17db98c812e4065a4d020ca41f/cffi-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (441 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 441.8/441.8 kB 36.2 MB/s eta 0:00:00
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/62/d5/5f610ebe421e85889f2e55e33b7f9a6795bd982198517d912eb1c76e1a53/pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 22.3 MB/s eta 0:00:00
# Collecting arrow>=0.15.0 (from isoduration->jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter)
#   Downloading https://mirrors.aliyun.com/pypi/packages/67/67/4bca5a595e2f89bff271724ddb1098e6c9e16f7f3d018d120255e3c30313/arrow-1.2.3-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 12.9 MB/s eta 0:00:00
# Installing collected packages: webencodings, json5, ipython-genutils, fastjsonschema, widgetsnbextension, websocket-client, webcolors, uri-template, tomli, tinycss2, terminado, soupsieve, send2trash, rfc3986-validator, rfc3339-validator, qtpy, python-json-logger, pycparser, prometheus-client, pandocfilters, overrides, mistune, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, fqdn, defusedxml, bleach, async-lru, jupyter-server-terminals, cffi, beautifulsoup4, arrow, isoduration, argon2-cffi-bindings, nbformat, ipywidgets, argon2-cffi, qtconsole, nbclient, jupyter-events, jupyter-console, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter
# Successfully installed argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.2.3 async-lru-2.0.4 beautifulsoup4-4.12.2 bleach-6.0.0 cffi-1.15.1 defusedxml-0.7.1 fastjsonschema-2.18.0 fqdn-1.5.1 ipython-genutils-0.2.0 ipywidgets-8.1.0 isoduration-20.11.0 json5-0.9.14 jsonpointer-2.4 jupyter-1.0.0 jupyter-console-6.6.3 jupyter-events-0.7.0 jupyter-lsp-2.2.0 jupyter-server-2.7.3 jupyter-server-terminals-0.4.4 jupyterlab-4.0.5 jupyterlab-pygments-0.2.2 jupyterlab-server-2.24.0 jupyterlab-widgets-3.0.8 mistune-3.0.1 nbclient-0.8.0 nbconvert-7.8.0 nbformat-5.9.2 notebook-7.0.3 notebook-shim-0.2.3 overrides-7.4.0 pandocfilters-1.5.0 prometheus-client-0.17.1 pycparser-2.21 python-json-logger-2.0.7 qtconsole-5.4.4 qtpy-2.4.0 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 send2trash-1.8.2 soupsieve-2.5 terminado-0.17.1 tinycss2-1.2.1 tomli-2.0.1 uri-template-1.3.0 webcolors-1.13 webencodings-0.5.1 websocket-client-1.6.2 widgetsnbextension-4.0.8
# Looking in indexes: https://mirror.baidu.com/pypi/simple/, https://mirrors.aliyun.com/pypi/simple/, https://pypi.tuna.tsinghua.edu.cn/simple/
# Collecting openpyxl
#   Downloading https://mirrors.aliyun.com/pypi/packages/6a/94/a59521de836ef0da54aaf50da6c4da8fb4072fb3053fa71f052fd9399e7a/openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 3.9 MB/s eta 0:00:00a 0:00:01
# Collecting et-xmlfile (from openpyxl)
#   Downloading https://mirrors.aliyun.com/pypi/packages/96/c2/3dd434b0108730014f1b96fd286040dc3bcb70066346f7e01ec2ac95865f/et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2

# %%
import pandas as pd

df1 = pd.read_excel('/home/aistudio/data/data237885/附件1.xlsx')
df2 = pd.read_excel('/home/aistudio/data/data237885/附件2.xlsx')
df3 = pd.read_excel('/home/aistudio/data/data237885/附件3.xlsx')
df4 = pd.read_excel('/home/aistudio/data/data237885/附件4.xlsx')

# %%
import calendar
import numpy as np

# 使用单品编码进行合并，并且只保留附件2中已有的单品编码
merged_df = pd.merge(df2, df1[['单品编码', '单品名称', '分类名称']], on='单品编码', how='left')

merged_df = pd.merge(merged_df, df3[['日期', '单品编码', '批发价格(元/千克)']], left_on=['销售日期', '单品编码'], right_on=['日期', '单品编码'], how='left')

# 添加一个序号列，从1开始
merged_df['序号'] = np.arange(1, len(merged_df) + 1)

# 如果你想让'序号'列成为第一列，你可以这样重新排列列的顺序：
cols = ['序号'] + [col for col in merged_df.columns if col != '序号']
merged_df = merged_df[cols]

# 转为日期格式
merged_df['销售日期'] = pd.to_datetime(merged_df['销售日期'])

# 添加“星期”列（1-7的数字表示）
merged_df['星期'] = pd.to_datetime(merged_df['销售日期']).dt.dayofweek + 1  # +1是为了让星期一开始为1

# 添加“年中进度”列
merged_df['年中进度'] = merged_df['销售日期'].apply(
    lambda x: x.timetuple().tm_yday / (366 if calendar.isleap(x.year) else 365)
)

# 新增一个表示所在周的列
merged_df['周'] = merged_df['销售日期'].dt.to_period('W')

# 新增一个表示所在月份的列
merged_df['月份'] = merged_df['销售日期'].dt.to_period('M')

# 创建一个新的列"季度"
merged_df['季度'] = merged_df['销售日期'].dt.to_period('Q')

# %%
def time_to_day_fraction(time_str):
    from datetime import datetime
    try:
        time_obj = datetime.strptime(time_str, '%H:%M:%S.%f').time()
    except ValueError:
        time_obj = datetime.strptime(time_str, '%H:%M:%S').time()

    total_seconds = time_obj.hour * 3600 + time_obj.minute * 60 + time_obj.second + time_obj.microsecond * 1e-6
    return total_seconds / 86400  # 86400 = 24*60*60

merged_df['扫码销售时间'] = merged_df['扫码销售时间'].apply(time_to_day_fraction)

# %%
# 将销售日期转换为字符串格式，以保持原来的格式（只包含日期部分）
merged_df['销售日期'] = merged_df['销售日期'].dt.strftime('%Y-%m-%d')

# 添加“交易金额”列
merged_df['交易金额'] = merged_df['销量(千克)'] * merged_df['销售单价(元/千克)']

# 计算“利润”列
merged_df['利润'] = merged_df['交易金额'] - (merged_df['销量(千克)'] * merged_df['批发价格(元/千克)'])

# 将“销售类型”列中的“销售”赋值为1，“退货”赋值为-1
merged_df['销售类型'] = merged_df['销售类型'].replace({'销售': 1, '退货': -1})

# 将“是否打折销售”列中的“是”赋值为1，“否”赋值为0
merged_df['是否打折销售'] = merged_df['是否打折销售'].replace({'是': 1, '否': 0})

# %%
merged_df.drop('日期', axis=1, inplace=True)

# %%
def QutlierReplacement(df, col, percentage=0.02):
    """
    传入DataFrame对象和需要处理异常值的列名。
    如果异常值的数据量小于数据量*百分比，就替换数据。
    """
    processed_records = {}  # 用于存储被处理的记录
    
    df = df.reset_index(drop=True)
    df_col = df[col]  # 获取列
    df_col_value = df[col].values
    
    # 计算下四分位数和上四分位数
    Q1 = df_col.quantile(q=0.25)
    Q3 = df_col.quantile(q=0.75)
    
    # 基于5倍的四分位差计算上对应的值
    up_whisker = Q3 + 5 * (Q3 - Q1)
    
    right = set(np.where(df_col_value > up_whisker)[0])  # 只考虑极大的异常值
    
    choose = list(right)
    
    if len(choose) < len(df) * percentage:
        for idx in choose:
            original_value = df.at[idx, col]
            item_name = df.at[idx, '单品名称']
            
            # 计算该单品名称下的销量(千克)的平均值
            mean_value = df[df['单品名称'] == item_name][col].mean()
            
            df.at[idx, col] = mean_value  # 使用该单品名称下的平均值进行替换
            processed_records[df.at[idx, '序号']] = (original_value, df.at[idx, col])  # 存储被处理的记录
    
    return df, processed_records  # 返回处理异常值后的数据和被处理的记录

# 使用该函数处理merged_df中的“销量(千克)”列
merged_df, processed_records = QutlierReplacement(merged_df, '销量(千克)')

count = 0
# 输出被处理的记录
for seq_no, (original_value, new_value) in processed_records.items():
    print(f"序号: {seq_no}, 处理前销量(千克): {original_value}, 处理后销量(千克): {new_value}")
    count += 1
    
print(count)
# Out:
# 序号: 606217, 处理前销量(千克): 5.0, 处理后销量(千克): 4.2408906882591095
# 序号: 638988, 处理前销量(千克): 5.0, 处理后销量(千克): 4.2393540297333185
# 序号: 628749, 处理前销量(千克): 5.0, 处理后销量(千克): 4.237814260562738
# 序号: 618515, 处理前销量(千克): 5.0, 处理后销量(千克): 4.236271374450517
# 序号: 630803, 处理前销量(千克): 5.0, 处理后销量(千克): 4.234725365087057
# 序号: 606231, 处理前销量(千克): 5.0, 处理后销量(千克): 4.233176226149985
# 序号: 618519, 处理前销量(千克): 5.0, 处理后销量(千克): 4.231623951304134
# 序号: 612380, 处理前销量(千克): 5.0, 处理后销量(千克): 4.2300685342015125
# 序号: 616476, 处理前销量(千克): 5.0, 处理后销量(千克): 4.228509968481272
# 序号: 614430, 处理前销量(千克): 10.0, 处理后销量(千克): 4.226948247769696
# 序号: 581667, 处理前销量(千克): 4.141, 处理后销量(千克): 0.447347337204992
# 序号: 620583, 处理前销量(千克): 5.0, 处理后销量(千克): 4.215261908190282
# 序号: 157740, 处理前销量(千克): 7.551, 处理后销量(千克): 1.2641466596389512
# 序号: 649260, 处理前销量(千克): 5.0, 处理后销量(千克): 4.213673369542894
# 序号: 157742, 处理前销量(千克): 9.694, 处理后销量(千克): 1.2637324513545682
# 序号: 694316, 处理前销量(千克): 3.03, 处理后销量(千克): 1.0119750312109863
# 序号: 655414, 处理前销量(千克): 5.0, 处理后销量(千克): 4.212081615230227
# 序号: 254012, 处理前销量(千克): 6.505, 处理后销量(千克): 0.6057634207240948
# 序号: 102468, 处理前销量(千克): 3.03, 处理后销量(千克): 1.2631770245823557
# 序号: 237636, 处理前销量(千克): 7.016, 处理后销量(千克): 0.478255547245076
# 序号: 673863, 处理前销量(千克): 3.02, 处理后销量(千克): 0.6910892198039964
# 序号: 630858, 处理前销量(千克): 5.0, 处理后销量(千克): 4.21048663874284
# 序号: 501844, 处理前销量(千克): 3.102, 处理后销量(千克): 0.6910299373608196
# 序号: 591956, 处理前销量(千克): 5.0, 处理后销量(千克): 4.2088884335581085
# 序号: 501846, 处理前销量(千克): 3.094, 处理后销量(千克): 0.6909685660979297
# 序号: 665686, 处理前销量(千克): 5.0, 处理后销量(千克): 4.20728699314021
# 序号: 634968, 处理前销量(千克): 5.0, 处理后销量(千克): 4.205682310940088
# 序号: 682072, 处理前销量(千克): 5.559, 处理后销量(千克): 0.5548977306218685
# 序号: 634971, 处理前销量(千克): 5.0, 处理后销量(千克): 4.204074380395434
# 序号: 614492, 处理前销量(千克): 5.0, 处理后销量(千克): 4.202463194930647
# 序号: 661596, 处理前销量(千克): 5.0, 处理后销量(千克): 4.200848747956822
# 序号: 659551, 处理前销量(千克): 5.0, 处理后销量(千克): 4.199231032871714
# 序号: 165984, 处理前销量(千克): 7.857, 处理后销量(千克): 1.2630606177451293
# 序号: 690272, 处理前销量(千克): 5.437, 处理后销量(千克): 0.4706581777023203
# 序号: 624739, 处理前销量(千克): 5.0, 处理后销量(千克): 4.197610043059714
# 序号: 247908, 处理前销量(千克): 3.333, 处理后销量(千克): 1.2626261771480642
# 序号: 665699, 处理前销量(千克): 5.0, 处理后销量(千克): 4.195985771891818
# 序号: 153705, 处理前销量(千克): 9.694, 处理后销量(千克): 1.2624897709138536
# 序号: 82030, 处理前销量(千克): 3.509, 处理后销量(千克): 0.39888838468674004
# 序号: 606321, 处理前销量(千克): 5.0, 处理后销量(千克): 4.194358212725607
# 序号: 624758, 处理前销量(千克): 5.0, 处理后销量(千克): 4.192727358905214
# 序号: 649336, 处理前销量(千克): 5.0, 处理后销量(千克): 4.191093203761297
# 序号: 657529, 处理前销量(千克): 5.0, 处理后销量(千克): 4.189455740611017
# 序号: 247930, 处理前销量(千克): 3.485, 处理后销量(千克): 1.2619342622678473
# 序号: 395388, 处理前销量(千克): 3.426, 处理后销量(千克): 0.3988104116224506
# 序号: 665725, 处理前销量(千克): 5.0, 处理后销量(千克): 4.187814962758003
# 序号: 632961, 处理前销量(千克): 5.0, 处理后销量(千克): 4.18617086349233
# 序号: 155778, 处理前销量(千克): 4.286, 处理后销量(千克): 1.2617877959522763
# 序号: 598147, 处理前销量(千克): 5.0, 处理后销量(千克): 4.184523436090492
# 序号: 606340, 处理前销量(千克): 5.0, 处理后销量(千克): 4.182872673815373
# 序号: 665729, 处理前销量(千克): 5.0, 处理后销量(千克): 4.181218569916213
# 序号: 643206, 处理前销量(千克): 5.0, 处理后销量(千克): 4.179561117628594
# 序号: 749707, 处理前销量(千克): 4.987, 处理后销量(千克): 0.49542892005099254
# 序号: 788626, 处理前销量(千克): 4.013, 处理后销量(千克): 0.6909073969128996
# 序号: 606355, 处理前销量(千克): 5.0, 处理后销量(千克): 4.177900310174402
# 序号: 53400, 处理前销量(千克): 3.269, 处理后销量(千克): 0.6908228330182048
# 序号: 696472, 处理前销量(千克): 25.0, 处理后销量(千克): 0.2509046075480435
# 序号: 643227, 处理前销量(千克): 5.0, 处理后销量(千克): 4.176236140761799
# 序号: 614557, 处理前销量(千克): 5.0, 处理后销量(千克): 4.174568602585203
# 序号: 624798, 处理前销量(千克): 5.0, 处理后销量(千克): 4.1728976888252545
# 序号: 606368, 处理前销量(千克): 5.0, 处理后销量(千克): 4.171223392648787
# 序号: 614560, 处理前销量(千克): 5.0, 处理后销量(千克): 4.169545707208805
# 序号: 620705, 处理前销量(千克): 5.0, 处理后销量(千克): 4.16786462564445
# 序号: 159907, 处理前销量(千克): 3.469, 处理后销量(千克): 1.2615885462353142
# 序号: 247971, 处理前销量(千克): 3.03, 处理后销量(千克): 1.2614431112996334
# 序号: 628901, 处理前销量(千克): 5.0, 处理后销量(千克): 4.166180141080978
# 序号: 450731, 处理前销量(千克): 5.789, 处理后销量(千克): 0.4131470290771176
# 序号: 172205, 处理前销量(千克): 3.061, 处理后销量(千克): 1.2613265902238198
# 序号: 325805, 处理前销量(千克): 10.0, 处理后销量(千克): 0.2503836726642857
# 序号: 612528, 处理前销量(千克): 5.0, 处理后销量(千克): 4.164492246629725
# 序号: 624816, 处理前销量(千克): 6.074, 处理后销量(千克): 0.5558022543835236
# 序号: 643251, 处理前销量(千克): 10.0, 处理后销量(千克): 4.162800935388084
# 序号: 606389, 处理前销量(千克): 7.0, 处理后销量(千克): 4.150984742949599
# 序号: 620725, 处理前销量(千克): 5.0, 处理后销量(千克): 4.145217505587149
# 序号: 653497, 处理前销量(千克): 5.0, 处理后销量(千克): 4.143487176651091
# 序号: 643261, 处理前销量(千克): 5.0, 处理后销量(千克): 4.141753345024878
# 序号: 612542, 处理前销量(千克): 5.0, 处理后销量(千克): 4.140016003618046
# 序号: 620735, 处理前销量(千克): 5.0, 处理后销量(千克): 4.138275145325775
# 序号: 628934, 处理前销量(千克): 5.0, 处理后销量(千克): 4.136530763028863
# 序号: 653510, 处理前销量(千克): 5.0, 处理后销量(千克): 4.134782849593699
# 序号: 635087, 处理前销量(千克): 5.0, 处理后销量(千克): 4.133031397872228
# 序号: 645331, 处理前销量(千克): 5.0, 处理后销量(千克): 4.13127640070193
# 序号: 665813, 处理前销量(千克): 5.0, 处理后销量(千克): 4.1295178509057795
# 序号: 733401, 处理前销量(千克): 3.51, 处理后销量(千克): 0.6907572054970902
# 序号: 28891, 处理前销量(千克): 4.274, 处理后销量(千克): 0.4845238688252386
# 序号: 624861, 处理前销量(千克): 5.0, 处理后销量(千克): 4.127755741292229
# 序号: 659679, 处理前销量(千克): 10.0, 处理后销量(千克): 4.125990064655168
# 序号: 620770, 处理前销量(千克): 5.0, 处理后销量(千克): 4.114099356284024
# 序号: 153832, 处理前销量(千克): 6.225, 处理后销量(千克): 1.2612080190412018
# 序号: 618729, 处理前销量(千克): 5.0, 处理后销量(千克): 4.1123060351428995
# 序号: 628969, 处理前销量(千克): 5.0, 处理后销量(千克): 4.110509083797035
# 序号: 733418, 处理前销量(千克): 3.269, 处理后销量(千克): 1.0116601084630479
# 序号: 612591, 处理前销量(千克): 5.0, 处理后销量(千克): 4.108708494897838
# 序号: 653555, 处理前销量(千克): 5.0, 处理后销量(千克): 4.1069042610818425
# 序号: 639228, 处理前销量(千克): 5.0, 处理后销量(千克): 4.105096374970672
# 序号: 108800, 处理前销量(千克): 3.271, 处理后销量(千克): 0.7957304687499999
# 序号: 620805, 处理前销量(千克): 5.0, 处理后销量(千克): 4.1032848291710176
# 序号: 620808, 处理前销量(千克): 5.0, 处理后销量(千克): 4.101469616274603
# 序号: 649482, 处理前销量(千克): 5.0, 处理后销量(千克): 4.099650728858155
# 序号: 620814, 处理前销量(千克): 5.0, 处理后销量(千克): 4.097828159483373
# 序号: 624911, 处理前销量(千克): 5.0, 处理后销量(千克): 4.096001900696902
# 序号: 631055, 处理前销量(千克): 5.0, 处理后销量(千克): 4.094171945030297
# 序号: 168210, 处理前销量(千克): 5.816, 处理后销量(千克): 1.2608809804339443
# 序号: 168211, 处理前销量(千克): 4.388, 处理后销量(千克): 1.2605808671766265
# 序号: 168213, 处理前销量(千克): 4.49, 处理后销量(千克): 1.2603748176883658
# 序号: 616732, 处理前销量(千克): 5.0, 处理后销量(千克): 4.092338284999993
# 序号: 416031, 处理前销量(千克): 3.243, 处理后销量(千克): 1.260162034371571
# 序号: 495905, 处理前销量(千克): 3.758, 处理后销量(千克): 0.6906854416484328
# 序号: 172326, 处理前销量(千克): 3.183, 处理后销量(千克): 0.6906073631309745
# 序号: 170280, 处理前销量(千克): 3.061, 处理后销量(千克): 1.260031395422722
# 序号: 207146, 处理前销量(千克): 5.556, 处理后销量(千克): 1.2599127389064104
# 序号: 620842, 处理前销量(千克): 5.0, 处理后销量(千克): 4.090500913107281
# 序号: 649517, 处理前销量(千克): 5.0, 处理后销量(千克): 4.0886598218382675
# 序号: 645425, 处理前销量(千克): 5.0, 处理后销量(千克): 4.086815003663851
# 序号: 641334, 处理前销量(千克): 5.0, 处理后销量(千克): 4.084966451039689
# 序号: 119102, 处理前销量(千克): 3.283, 处理后销量(千克): 0.6905439192557838
# 序号: 620863, 处理前销量(千克): 5.0, 处理后销量(千克): 4.083114156406166
# 序号: 612672, 处理前销量(千克): 5.0, 处理后销量(千克): 4.081258112188364
# 序号: 579908, 处理前销量(千克): 160.0, 处理后销量(千克): 4.878048780487805
# 序号: 649543, 处理前销量(千克): 5.0, 处理后销量(千克): 4.079398310796034
# 序号: 631114, 处理前销量(千克): 5.0, 处理后销量(千克): 4.077534744623556
# 序号: 612692, 处理前销量(千克): 5.0, 处理后销量(千克): 4.075667406049919
# 序号: 627034, 处理前销量(千克): 5.0, 处理后销量(千克): 4.073796287438684
# 序号: 655723, 处理前销量(千克): 5.0, 处理后销量(千克): 4.071921381137953
# 序号: 639344, 处理前销量(千克): 5.0, 处理后销量(千克): 4.070042679480338
# 序号: 725361, 处理前销量(千克): 3.921, 处理后销量(千克): 0.6904779282648014
# 序号: 725362, 处理前销量(千克): 3.381, 处理后销量(千克): 0.6903956952987398
# 序号: 715128, 处理前销量(千克): 3.553, 处理后销量(千克): 0.5534228994195761
# 序号: 655737, 处理前销量(千克): 5.0, 处理后销量(千克): 4.068160174782929
# 序号: 188794, 处理前销量(千克): 3.044, 处理后销量(千克): 1.259629691913322
# 序号: 631164, 处理前销量(千克): 5.0, 处理后销量(千克): 4.066273859347267
# 序号: 647548, 处理前销量(千克): 5.0, 处理后销量(千克): 4.064383725459306
# 序号: 160126, 处理前销量(千克): 4.082, 处理后销量(千克): 1.259512128973008
# 序号: 608638, 处理前销量(千克): 5.0, 处理后销量(千克): 4.062489765389385
# 序号: 725377, 处理前销量(千克): 3.921, 处理后销量(千克): 0.6903272059439045
# 序号: 217480, 处理前销量(千克): 4.04, 处理后销量(千克): 1.259326169830102
# 序号: 637326, 处理前销量(千克): 5.0, 处理后销量(千克): 4.060591971392197
# 序号: 721297, 处理前销量(千克): 3.061, 处理后销量(千克): 1.0113078394412724
# 序号: 629144, 处理前销量(千克): 5.0, 处理后销量(千克): 4.058690335706757
# 序号: 633241, 处理前销量(千克): 4.239, 处理后销量(千克): 0.6045359474450113
# 序号: 135578, 处理前销量(千克): 3.939, 处理后销量(千克): 1.2591429655983082
# 序号: 629156, 处理前销量(千克): 5.0, 处理后销量(千克): 4.056784850556366
# 序号: 647588, 处理前销量(千克): 5.0, 处理后销量(千克): 4.054875508148585
# 序号: 182694, 处理前销量(千克): 5.102, 处理后销量(千克): 1.2589664036642982
# 序号: 149931, 处理前销量(千克): 6.531, 处理后销量(千克): 1.2587132060363937
# 序号: 213420, 处理前销量(千克): 3.889, 处理后销量(千克): 1.2583658422998034
# 序号: 618924, 处理前销量(千克): 5.0, 处理后销量(千克): 4.052962300675202
# 序号: 631219, 处理前销量(千克): 5.0, 处理后销量(千克): 4.051045220312196
# 序号: 547253, 处理前销量(千克): 5.227, 处理后销量(千克): 0.43551538749532015
# 序号: 479670, 处理前销量(千克): 3.708, 处理后销量(千克): 0.6902449691412049
# 序号: 618934, 处理前销量(千克): 5.0, 处理后销量(千克): 4.0491242592197105
# 序号: 608711, 处理前销量(千克): 5.0, 处理后销量(千克): 4.047199409542018
# 序号: 618953, 处理前销量(千克): 5.0, 处理后销量(千克): 4.0452706634074875
# 序号: 627148, 处理前销量(千克): 5.0, 处理后销量(千克): 4.043338012928555
# 序号: 631250, 处理前销量(千克): 5.0, 处理后销量(千克): 4.041401450201691
# 序号: 221655, 处理前销量(千克): 5.0, 处理后销量(千克): 1.0079946702198535
# 序号: 618968, 处理前销量(千克): 5.0, 处理后销量(千克): 4.039460967307361
# 序号: 666079, 处理前销量(千克): 5.0, 处理后销量(千克): 4.037516556310008
# 序号: 160226, 处理前销量(千克): 8.878, 处理后销量(千克): 1.2581925234068203
# 序号: 160227, 处理前销量(千克): 11.837, 处理后销量(千克): 1.2576904936613602
# 序号: 160228, 处理前销量(千克): 10.102, 处理后销量(千克): 1.2569934776179856
# 序号: 160229, 处理前销量(千克): 10.204, 处理后销量(千克): 1.2564107258376207
# 序号: 631274, 处理前销量(千克): 5.0, 处理后销量(千克): 4.035568209258004
# 序号: 608759, 处理前销量(千克): 10.0, 处理后销量(千克): 4.033615918183628
# 序号: 608761, 处理前销量(千克): 5.0, 处理后销量(千克): 4.021538217613149
# 序号: 172540, 处理前销量(千克): 3.265, 处理后销量(千克): 1.2558212154097537
# 序号: 621052, 处理前销量(千克): 5.0, 处理后销量(千克): 4.019557525745969
# 序号: 631292, 处理前销量(千克): 4.95, 处理后销量(千克): 0.3615218216318785
# 序号: 156160, 处理前销量(千克): 8.367, 处理后销量(千克): 1.2556888410004383
# 序号: 647682, 处理前销量(千克): 5.0, 处理后销量(千克): 4.017572824381083
# 序号: 645636, 处理前销量(千克): 5.0, 处理后销量(千克): 4.015584105402097
# 序号: 649734, 处理前销量(千克): 5.0, 处理后销量(千克): 4.01359136067619
# 序号: 629255, 处理前销量(千克): 5.0, 处理后销量(千克): 4.0115945820540775
# 序号: 154120, 处理前销量(千克): 4.898, 处理后销量(千克): 1.255220313450102
# 序号: 612881, 处理前销量(千克): 5.0, 处理后销量(千克): 4.009593761369977
# 序号: 692756, 处理前销量(千克): 4.52, 处理后销量(千克): 0.4702566624769749
# 序号: 633369, 处理前销量(千克): 5.0, 处理后销量(千克): 4.007588890441575
# 序号: 641563, 处理前销量(千克): 5.0, 处理后销量(千克): 4.00557996107
# 序号: 608797, 处理前销量(千克): 5.0, 处理后销量(千克): 4.003566965039777
# 序号: 608801, 处理前销量(千克): 5.0, 处理后销量(千克): 4.0015498941188055
# 序号: 645668, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9995287400583166
# 序号: 715301, 处理前销量(千克): 9.082, 处理后销量(千克): 1.0109879748718968
# 序号: 657965, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9975034945928476
# 序号: 805424, 处理前销量(千克): 6.0, 处理后销量(千克): 1.007329779258864
# 序号: 180785, 处理前销量(千克): 5.0, 处理后销量(千克): 1.254980309517664
# 序号: 608830, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9954741494402017
# 序号: 631360, 处理前销量(千克): 5.0, 处理后销量(千克): 3.993440696301416
# 序号: 653890, 处理前销量(千克): 5.0, 处理后销量(千克): 3.991403126860731
# 序号: 178755, 处理前销量(千克): 3.763, 处理后销量(千克): 0.6901681521619288
# 序号: 608836, 处理前销量(千克): 5.0, 处理后销量(千克): 3.98936143278555
# 序号: 614981, 处理前销量(千克): 5.0, 处理后销量(千克): 3.987315605726412
# 序号: 338502, 处理前销量(千克): 3.597, 处理后销量(千克): 0.4026639645435699
# 序号: 633413, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9852656373169513
# 序号: 627272, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9832115191738677
# 序号: 154188, 处理前销量(千克): 11.531, 处理后销量(千克): 1.2547335695196087
# 序号: 154189, 处理前销量(千克): 8.367, 处理后销量(千克): 1.2540565194187732
# 序号: 617038, 处理前销量(千克): 5.0, 处理后销量(千克): 3.981153242896892
# 序号: 641616, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9790908000687484
# 序号: 830033, 处理前销量(千克): 4.496, 处理后销量(千克): 0.690089933201821
# 序号: 477778, 处理前销量(千克): 3.322, 处理后销量(千克): 0.6899930537295849
# 序号: 631381, 处理前销量(千克): 5.0, 处理后销量(千克): 3.977024182255122
# 序号: 631382, 处理前销量(千克): 5.0, 处理后销量(千克): 3.974953381004626
# 序号: 164439, 处理前销量(千克): 3.265, 处理后销量(千克): 1.253587884323202
# 序号: 760409, 处理前销量(千克): 17.0, 处理后销量(千克): 1.0064982219269618
# 序号: 123483, 处理前销量(千克): 9.95, 处理后销量(千克): 1.2534553627712401
# 序号: 619100, 处理前销量(千克): 5.0, 处理后销量(千克): 3.972878387848765
# 序号: 637531, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9707991943019003
# 序号: 643679, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9687157918612157
# 序号: 631392, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9666281720066836
# 序号: 416356, 处理前销量(千克): 3.547, 处理后销量(千克): 1.2528823923774315
# 序号: 246373, 处理前销量(千克): 3.081, 处理后销量(千克): 1.2527312448212564
# 序号: 633444, 处理前销量(千克): 10.0, 处理后销量(千克): 3.9645363262010296
# 序号: 633445, 处理前销量(千克): 10.0, 处理后销量(千克): 3.952318788399817
# 序号: 660069, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9400765187407076
# 序号: 506473, 处理前销量(千克): 4.0, 处理后销量(千克): 1.024390243902439
# 序号: 643693, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9379309246490894
# 序号: 449139, 处理前销量(千克): 3.521, 处理后销量(千克): 0.6899260559709931
# 序号: 604799, 处理前销量(千克): 5.0, 处理后销量(千克): 3.935780987249594
# 序号: 606849, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9336266977500993
# 序号: 643713, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9314680473406862
# 序号: 510600, 处理前销量(千克): 8.014, 处理后销量(千克): 0.1085379077615298
# 序号: 621200, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9293050271936028
# 序号: 180883, 处理前销量(千克): 3.265, 处理后销量(千克): 1.252610789639073
# 序号: 625304, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9271376284632256
# 序号: 633499, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9249658422860256
# 序号: 191135, 处理前销量(千克): 3.883, 处理后销量(千克): 0.5881154116819142
# 序号: 635557, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9227896597805314
# 序号: 109222, 处理前销量(千克): 3.38, 处理后销量(千克): 0.6898539909603267
# 序号: 662190, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9206090720472933
# 序号: 604847, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9184240701688466
# 序号: 604848, 处理前销量(千克): 5.0, 处理后销量(千克): 3.916234645209674
# 序号: 635568, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9140407882161714
# 序号: 201397, 处理前销量(千克): 4.651, 处理后销量(千克): 1.252478203711391
# 序号: 258742, 处理前销量(千克): 5.418, 处理后销量(千克): 0.39873451748179384
# 序号: 201399, 处理前销量(千克): 3.915, 处理后销量(千克): 1.2522542926693372
# 序号: 604853, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9118424902166096
# 序号: 619190, 处理前销量(千克): 5.0, 处理后销量(千克): 3.909639742221097
# 序号: 613050, 处理前销量(千克): 5.0, 处理后销量(千克): 3.907432535221544
# 序号: 721593, 处理前销量(千克): 3.112, 处理后销量(千克): 1.0097284536445048
# 序号: 619201, 处理前销量(千克): 5.0, 处理后销量(千克): 3.9052208601916276
# 序号: 633544, 处理前销量(千克): 5.0, 处理后销量(千克): 3.903004708086753
# 序号: 606924, 处理前销量(千克): 5.0, 处理后销量(千克): 3.900784069844013
# 序号: 641742, 处理前销量(千克): 5.0, 处理后销量(千克): 3.898558936382159
# 序号: 154328, 处理前销量(千克): 3.411, 处理后销量(千克): 0.4774405703748747
# 序号: 238302, 处理前销量(千克): 3.69, 处理后销量(千克): 0.6897855132714115
# 序号: 647905, 处理前销量(千克): 3.534, 处理后销量(千克): 0.6897091427868315
# 序号: 604900, 处理前销量(千克): 5.0, 处理后销量(千克): 3.896329298601556
# 序号: 453360, 处理前销量(千克): 3.171, 处理后销量(千克): 0.6896367413395306
# 序号: 656116, 处理前销量(千克): 10.0, 处理后销量(千克): 3.8940951473841503
# 序号: 631544, 处理前销量(千克): 5.0, 处理后销量(千克): 3.8817350161035513
# 序号: 635661, 处理前销量(千克): 5.0, 处理后销量(千克): 3.879471321804166
# 序号: 604945, 处理前销量(千克): 5.0, 处理后销量(千克): 3.877203045127656
# 序号: 762652, 处理前销量(千克): 3.175, 处理后销量(千克): 0.6895735782172534
# 序号: 158493, 处理前销量(千克): 7.755, 处理后销量(千克): 1.2520788581122593
# 序号: 158494, 处理前销量(千克): 8.061, 处理后销量(千克): 1.251650414236789
# 序号: 635679, 处理前销量(千克): 5.0, 处理后销量(千克): 3.874930176797955
# 序号: 232226, 处理前销量(千克): 4.0, 处理后销量(千克): 1.0020540910647038
# 序号: 660270, 处理前销量(千克): 5.0, 处理后销量(千克): 3.8726527075202184
# 序号: 277295, 处理前销量(千克): 3.521, 处理后销量(千克): 0.6895103116671253
# 序号: 660272, 处理前销量(千克): 5.0, 处理后销量(千克): 3.8703706279807855
# 序号: 643893, 处理前销量(千克): 5.0, 处理后销量(千克): 3.868083928847143
# 序号: 625465, 处理前销量(千克): 5.0, 处理后销量(千克): 3.865792600767887
# 序号: 631612, 处理前销量(千克): 5.0, 处理后销量(千克): 3.86349663437268
# 序号: 172861, 处理前销量(千克): 3.265, 处理后销量(千克): 1.251201781374372
# 序号: 635709, 处理前销量(千克): 5.0, 处理后销量(千克): 3.8611960202722195
# 序号: 615232, 处理前销量(千克): 6.0, 处理后销量(千克): 3.858890749058196
# 序号: 607045, 处理前销量(千克): 5.0, 处理后销量(千克): 3.8545565198052776
# 序号: 619334, 处理前销量(千克): 5.0, 处理后销量(千克): 3.8522378083069073
# 序号: 183113, 处理前销量(千克): 6.735, 处理后销量(千克): 1.2510691026144154
# 序号: 502603, 处理前销量(千克): 3.094, 处理后销量(千克): 0.6894382360736842
# 序号: 639819, 处理前销量(千克): 5.0, 处理后销量(千克): 3.8499144030605645
# 序号: 207693, 处理前销量(千克): 3.283, 处理后销量(千克): 1.2507077947413499
# 序号: 600910, 处理前销量(千克): 6.0, 处理后销量(千克): 3.847586294564736
# 序号: 613199, 处理前销量(千克): 10.0, 处理后销量(千克): 3.8432291818006967
# 序号: 613200, 处理前销量(千克): 5.0, 处理后销量(千克): 3.8307660829784314
# 序号: 619346, 处理前销量(千克): 5.0, 处理后销量(千克): 3.82839921270106
# 序号: 90967, 处理前销量(千克): 8.998, 处理后销量(千克): 0.45702691660658495
# 序号: 90968, 处理前销量(千克): 6.003, 处理后销量(千克): 0.3986086803548472
# 序号: 90969, 处理前销量(千克): 7.004, 处理后销量(千克): 0.3829475491356855
# 序号: 179032, 处理前销量(千克): 3.061, 处理后销量(千克): 1.2505738975081664
# 序号: 90971, 处理前销量(千克): 3.998, 处理后销量(千克): 0.4674854087089381
# 序号: 172894, 处理前销量(千克): 3.271, 处理后销量(千克): 0.6893770279340908
# 序号: 684898, 处理前销量(千克): 8.0, 处理后销量(千克): 0.9997906197654941
# 序号: 549731, 处理前销量(千克): 10.0, 处理后销量(千克): 0.21694205729166668
# 序号: 684899, 处理前销量(千克): 8.0, 处理后销量(千克): 1.0008664259927798
# 序号: 152422, 处理前销量(千克): 3.101, 处理后销量(千克): 1.250454617886181
# 序号: 633702, 处理前销量(千克): 5.0, 处理后销量(千克): 3.8260275511883086
# 序号: 633715, 处理前销量(千克): 5.0, 处理后销量(千克): 3.8236510887413213
# 序号: 664443, 处理前销量(千克): 5.0, 处理后销量(千克): 3.8212698156416076
# 序号: 607122, 处理前销量(千克): 5.0, 处理后销量(千克): 3.8188837221510035
# 序号: 605095, 处理前销量(千克): 5.0, 处理后销量(千克): 3.816492798511633
# 序号: 625578, 处理前销量(千克): 5.0, 处理后销量(千克): 3.8140970349458674
# 序号: 510898, 处理前销量(千克): 4.596, 处理后销量(千克): 0.47707488109170026
# 序号: 648117, 处理前销量(千克): 5.0, 处理后销量(千克): 3.811696421656284
# 序号: 725949, 处理前销量(千克): 3.418, 处理后销量(千克): 1.009400383802689
# 序号: 629696, 处理前销量(千克): 5.0, 处理后销量(千克): 3.8092909488256286
# 序号: 623553, 处理前销量(千克): 5.0, 处理后销量(千克): 3.8068806066167737
# 序号: 168898, 处理前销量(千克): 8.163, 处理后销量(千克): 1.2503326950121456
# 序号: 615364, 处理前销量(千克): 5.0, 处理后销量(千克): 3.804465385172678
# 序号: 226245, 处理前销量(千克): 4.0, 处理后销量(千克): 1.0051261829652998
# 序号: 605130, 处理前销量(千克): 5.0, 处理后销量(千克): 3.8020452746163476
# 序号: 502732, 处理前销量(千克): 3.579, 处理后销量(千克): 0.6893113126999794
# 序号: 635857, 处理前销量(千克): 5.0, 处理后销量(千克): 3.7996202650507938
# 序号: 635859, 处理前销量(千克): 5.0, 处理后销量(千克): 3.797190346558993
# 序号: 166873, 处理前销量(千克): 3.469, 处理后销量(千克): 1.2498772550790196
# 序号: 609243, 处理前销量(千克): 5.0, 处理后销量(千克): 3.7947555092038496
# 序号: 725982, 处理前销量(千克): 3.622, 处理后销量(千克): 1.009024509954968
# 序号: 725995, 处理前销量(千克): 3.219, 处理后销量(千克): 0.689237755650538
# 序号: 162800, 处理前销量(千克): 7.041, 处理后销量(千克): 1.249731048546873
# 序号: 162801, 处理前销量(千克): 10.918, 处理后销量(千克): 1.249349491757345
# 序号: 162802, 处理前销量(千克): 12.143, 处理后销量(千克): 1.2487124743302636
# 序号: 394226, 处理前销量(千克): 5.547, 处理后销量(千克): 0.39846817364038767
# 序号: 162804, 处理前销量(千克): 11.531, 处理后销量(千克): 1.2479947060125887
# 序号: 162805, 处理前销量(千克): 14.592, 处理后销量(千克): 1.2473172119228544
# 序号: 162806, 处理前销量(千克): 12.959, 处理后销量(千克): 1.246437999721769
# 序号: 623600, 处理前销量(千克): 5.0, 处理后销量(千克): 3.792315743028149
# 序号: 678900, 处理前销量(千克): 3.275, 处理后销量(千克): 0.7953100765062414
# 序号: 214014, 处理前销量(千克): 3.083, 处理后销量(千克): 0.5869560574988325
# 序号: 101374, 处理前销量(千克): 3.03, 处理后销量(千克): 1.2456663195267312
# 序号: 605184, 处理前销量(千克): 5.0, 处理后销量(千克): 3.789871038054522
# 序号: 58369, 处理前销量(千克): 5.0, 处理后销量(千克): 3.787421384285402
# 序号: 97284, 处理前销量(千克): 16.003, 处理后销量(千克): 0.5554182996280534
# 序号: 152583, 处理前销量(千克): 3.986, 处理后销量(千克): 1.2455487589996215
# 序号: 656392, 处理前销量(千克): 5.0, 处理后销量(千克): 3.7849667717029836
# 序号: 152585, 处理前销量(千克): 4.855, 处理后销量(千克): 1.24536820482641
# 序号: 152586, 处理前销量(千克): 4.493, 处理后销量(千克): 1.2451303848372697
# 序号: 152587, 处理前销量(千克): 5.073, 处理后销量(千克): 1.2449163994890577
# 序号: 164873, 处理前销量(千克): 4.796, 处理后销量(千克): 1.244664186839136
# 序号: 726029, 处理前销量(千克): 4.031, 处理后销量(千克): 1.0086167422442867
# 序号: 199694, 处理前销量(千克): 6.01, 处理后销量(千克): 1.2444302076710534
# 序号: 646164, 处理前销量(千克): 5.0, 处理后销量(千克): 3.7825071902691834
# 序号: 349218, 处理前销量(千克): 5.0, 处理后销量(千克): 3.780042629925599
# 序号: 615460, 处理前销量(千克): 5.0, 处理后销量(千克): 3.777573080593465
# 序号: 664614, 处理前销量(千克): 5.0, 处理后销量(千克): 3.7750985321736135
# 序号: 169000, 处理前销量(千克): 4.286, 处理后销量(千克): 1.2441162288996517
# 序号: 609322, 处理前销量(千克): 5.0, 处理后销量(千克): 3.7726189745464347
# 序号: 617515, 处理前销量(千克): 5.0, 处理后销量(千克): 3.770134397571832
# 序号: 623660, 处理前销量(千克): 5.0, 处理后销量(千克): 3.7676447910891837
# 序号: 613422, 处理前销量(千克): 5.0, 处理后销量(千克): 3.765150144917299
# 序号: 721972, 处理前销量(千克): 4.184, 处理后销量(千克): 1.008145084432527
# 序号: 613429, 处理前销量(千克): 5.0, 处理后销量(千克): 3.762650448854379
# 序号: 758844, 处理前销量(千克): 6.0, 处理后销量(千克): 1.0038344141691216
# 序号: 642119, 处理前销量(千克): 5.0, 处理后销量(千克): 3.7601456926779706
# 序号: 502856, 处理前销量(千克): 3.136, 处理后销量(千克): 0.6891733605316798
# 序号: 629834, 处理前销量(千克): 5.0, 处理后销量(千克): 3.7576358661449305
# 序号: 173135, 处理前销量(千克): 3.571, 处理后销量(千克): 1.2439158148944405
# 序号: 732242, 处理前销量(千克): 3.206, 处理后销量(千克): 0.6891110765393298
# 序号: 500819, 处理前销量(千克): 3.754, 处理后销量(千克): 0.6890470091109612
# 序号: 535643, 处理前销量(千克): 5.0, 处理后销量(千克): 0.40261829528864884
# 序号: 726114, 处理前销量(千克): 4.082, 处理后销量(千克): 1.0076494766117456
# 序号: 609385, 处理前销量(千克): 5.0, 处理后销量(千克): 3.755120958991378
# 序号: 646254, 处理前销量(千克): 5.0, 处理后销量(千克): 3.752600960932656
# 序号: 629878, 处理前销量(千克): 5.0, 处理后销量(千克): 3.7500758616632885
# 序号: 588919, 处理前销量(千克): 8.672, 处理后销量(千克): 0.43515660916417037
# 序号: 627831, 处理前销量(千克): 5.0, 处理后销量(千克): 3.7475456508569387
# 序号: 482428, 处理前销量(千克): 3.691, 处理后销量(千克): 0.6889689907072222
# 序号: 150653, 处理前销量(千克): 3.163, 处理后销量(千克): 1.243762495340803
# 序号: 609407, 处理前销量(千克): 5.0, 处理后销量(千克): 3.745010318166366
# 序号: 621696, 处理前销量(千克): 5.0, 处理后销量(千克): 3.742469853223383
# 序号: 726151, 处理前销量(千克): 4.286, 处理后销量(千克): 1.007169709051916
# 序号: 623756, 处理前销量(千克): 5.0, 处理后销量(千克): 3.739924245638815
# 序号: 476301, 处理前销量(千克): 3.406, 处理后销量(千克): 0.6888925739830452
# 序号: 633999, 处理前销量(千克): 5.0, 处理后销量(千克): 3.7373734850024563
# 序号: 486544, 处理前销量(千克): 13.993, 处理后销量(千克): 0.6888234099910375
# 序号: 629912, 处理前销量(千克): 5.0, 处理后销量(千克): 3.7348175608830276
# 序号: 609434, 处理前销量(千克): 5.0, 处理后销量(千克): 3.732256462828135
# 序号: 726176, 处理前销量(千克): 5.0, 处理后销量(千克): 1.0066580314160003
# 序号: 615586, 处理前销量(千克): 5.0, 处理后销量(千克): 3.7296901803642246
# 序号: 664738, 处理前销量(千克): 5.0, 处理后销量(千克): 3.727118702996541
# 序号: 595111, 处理前销量(千克): 12.5, 处理后销量(千克): 0.4952653224884374
# 序号: 595113, 处理前销量(千克): 10.0, 处理后销量(千克): 0.4025525667633116
# 序号: 660657, 处理前销量(千克): 5.0, 处理后销量(千克): 3.724542020209085
# 序号: 150706, 处理前销量(千克): 4.796, 处理后销量(千克): 1.2436360466977237
# 序号: 150707, 处理前销量(千克): 3.776, 处理后销量(千克): 1.243401999790799
# 序号: 464052, 处理前销量(千克): 5.552, 处理后销量(千克): 0.46742547297188203
# 序号: 623796, 处理前销量(千克): 5.0, 处理后销量(千克): 3.721960121464569
# 序号: 636090, 处理前销量(千克): 5.0, 处理后销量(千克): 3.719372996204376
# 序号: 29886, 处理前销量(千克): 3.07, 处理后销量(千克): 0.4829508193726963
# 序号: 627908, 处理前销量(千克): 5.0, 处理后销量(千克): 3.716780633848514
# 序号: 828612, 处理前销量(千克): 3.214, 处理后销量(千克): 0.6884847520658751
# 序号: 627916, 处理前销量(千克): 5.0, 处理后销量(千克): 3.7141830237955755
# 序号: 150733, 处理前销量(千克): 8.061, 处理后销量(千克): 1.2432351399937107
# 序号: 144590, 处理前销量(千克): 3.305, 处理后销量(千克): 1.242785952692353
# 序号: 441550, 处理前销量(千克): 15.0, 处理后销量(千克): 0.25017845646677916
# 序号: 441551, 处理前销量(千克): 8.0, 处理后销量(千克): 0.36730467539783124
# 序号: 441552, 处理前销量(千克): 6.496, 处理后销量(千克): 0.5496912901113294
# 序号: 441553, 处理前销量(千克): 8.504, 处理后销量(千克): 0.43938997459448903
# 序号: 441554, 处理前销量(千克): 7.5, 处理后销量(千克): 0.6884204650543457
# 序号: 441555, 处理前销量(千克): 5.0, 处理后销量(千克): 0.24986799273267546
# 序号: 441556, 处理前销量(千克): 3.5, 处理后销量(千克): 0.366767237338079
# 序号: 623834, 处理前销量(千克): 5.0, 处理后销量(千克): 3.711580155422692
# 序号: 640226, 处理前销量(千克): 5.0, 处理后销量(千克): 3.7089720180854915
# 序号: 623843, 处理前销量(千克): 5.0, 处理后销量(千克): 3.706358601118053
# 序号: 597220, 处理前销量(千克): 3.07, 处理后销量(千克): 1.0060348507092924
# 序号: 103662, 处理前销量(千克): 3.131, 处理后销量(千克): 1.242650084063594
# 序号: 658671, 处理前销量(千克): 6.0, 处理后销量(千克): 3.703739893832867
# 序号: 640240, 处理前销量(千克): 5.0, 处理后销量(千克): 3.6990915940228124
# 序号: 662779, 处理前销量(千克): 5.0, 处理后销量(千克): 3.6964581761969475
# 序号: 654588, 处理前销量(千克): 5.0, 处理后销量(千克): 3.6938194275657668
# 序号: 126205, 处理前销量(千克): 12.172, 处理后销量(千克): 1.242525670444149
# 序号: 599300, 处理前销量(千克): 5.0, 处理后销量(千克): 3.6911753373381675
# 序号: 662788, 处理前销量(千克): 5.0, 处理后销量(千克): 3.6885258947012
# 序号: 650505, 处理前销量(千克): 5.0, 处理后销量(千克): 3.685871088820029
# 序号: 644362, 处理前销量(千克): 5.0, 处理后销量(千克): 3.683210908837883
# 序号: 625931, 处理前销量(千克): 5.0, 处理后销量(千克): 3.680545343876016
# 序号: 181516, 处理前销量(千克): 3.061, 处理后销量(千克): 1.241805583849765
# 序号: 640271, 处理前销量(千克): 5.0, 处理后销量(千克): 3.6778743830336595
# 序号: 150803, 处理前销量(千克): 12.245, 处理后销量(千克): 1.2416857265288959
# 序号: 167187, 处理前销量(千克): 9.082, 处理后销量(千克): 1.2409607750021159
# 序号: 638229, 处理前销量(千克): 5.0, 处理后销量(千克): 3.675198015387979
# 序号: 693527, 处理前销量(千克): 3.106, 处理后销量(千克): 1.0057127587696404
# 序号: 658712, 处理前销量(千克): 5.0, 处理后销量(千克): 3.6725162299940277
# 序号: 625946, 处理前销量(千克): 5.0, 处理后销量(千克): 3.669829015884704
# 序号: 298272, 处理前销量(千克): 3.165, 处理后销量(千克): 1.2404441694397887
# 序号: 486690, 处理前销量(千克): 3.289, 处理后销量(千克): 0.6882470762409322
# 序号: 99621, 处理前销量(千克): 20.0, 处理后销量(千克): 0.4386019532904627
# 序号: 617765, 处理前销量(千克): 5.0, 处理后销量(千克): 3.6671363620707047
# 序号: 128303, 处理前销量(千克): 3.03, 处理后销量(千克): 1.240317370399694
# 序号: 662832, 处理前销量(千克): 5.0, 处理后销量(千克): 3.6644382575404832
# 序号: 605490, 处理前销量(千克): 5.0, 处理后销量(千克): 3.6617346912602007
# 序号: 617780, 处理前销量(千克): 5.0, 处理后销量(千克): 3.659025652173683
# 序号: 638271, 处理前销量(千克): 5.0, 处理后销量(千克): 3.6563111292023747
# 序号: 595270, 处理前销量(千克): 4.0, 处理后销量(千克): 3.6535911112452943
# 序号: 617801, 处理前销量(千克): 5.0, 处理后销量(千克): 3.652889878676965
# 序号: 638281, 处理前销量(千克): 5.0, 处理后销量(千克): 3.6501629351115343
# 序号: 642378, 处理前销量(千克): 5.0, 处理后销量(千克): 3.6474304714174277
# 序号: 763214, 处理前销量(千克): 8.0, 处理后销量(千克): 1.003002274664486
# 序号: 630095, 处理前销量(千克): 5.0, 处理后销量(千克): 3.644692476420297
# 序号: 775504, 处理前销量(千克): 5.03, 处理后销量(千克): 0.405821682464455
# 序号: 154961, 处理前销量(千克): 4.796, 处理后销量(千克): 1.2401994574579625
# 序号: 646484, 处理前销量(千克): 5.0, 处理后销量(千克): 3.641948938923172
# 序号: 658781, 处理前销量(千克): 5.0, 处理后销量(千克): 3.6391998477064176
# 序号: 617822, 处理前销量(千克): 5.0, 处理后销量(千克): 3.636445191527686
# 序号: 654694, 处理前销量(千克): 5.0, 处理后销量(千克): 3.633684959121871
# 序号: 617836, 处理前销量(千克): 5.0, 处理后销量(千克): 3.6309191392010653
# 序号: 122221, 处理前销量(千克): 10.152, 处理后销量(千克): 1.2399651841319286
# 序号: 204141, 处理前销量(千克): 7.727, 处理后销量(千克): 1.23937801620362
# 序号: 607602, 处理前销量(千克): 5.0, 处理后销量(千克): 3.6281477204545087
# 序号: 630130, 处理前销量(千克): 5.0, 处理后销量(千克): 3.625370691548546
# 序号: 654707, 处理前销量(千克): 10.0, 处理后销量(千克): 3.62258804112658
# 序号: 122236, 处理前销量(千克): 3.788, 处理后销量(千克): 1.2389505803106304
# 序号: 611708, 处理前销量(千克): 5.0, 处理后销量(千克): 3.609678300319144
# 序号: 300423, 处理前销量(千克): 3.291, 处理后销量(千克): 1.2387826366145118
# 序号: 613770, 处理前销量(千克): 5.0, 处理后销量(千克): 3.606863883923029
# 序号: 646539, 处理前销量(千克): 5.0, 处理后销量(千克): 3.6040437703277313
# 序号: 259468, 处理前销量(千克): 3.131, 处理后销量(千克): 1.2386474266156065
# 序号: 626060, 处理前销量(千克): 5.0, 处理后销量(千克): 3.601217948000459
# 序号: 613775, 处理前销量(千克): 5.0, 处理后销量(千克): 3.5983864053850754
# 序号: 183697, 处理前销量(千克): 4.286, 处理后销量(千克): 1.2385227492817426
# 序号: 148885, 处理前销量(千克): 12.551, 处理后销量(千克): 1.2383219667510588
# 序号: 585111, 处理前销量(千克): 7.93, 处理后销量(千克): 0.44711913674392717
# 序号: 630168, 处理前销量(千克): 5.0, 处理后销量(千克): 3.5955491309020493
# 序号: 746907, 处理前销量(千克): 3.403, 处理后销量(千克): 0.6881808740537423
# 序号: 628127, 处理前销量(千克): 10.0, 处理后销量(千克): 3.5927061129484095
# 序号: 257443, 处理前销量(千克): 3.081, 处理后销量(千克): 1.237576632844533
# 序号: 218537, 处理前销量(千克): 3.02, 处理后销量(千克): 0.5860777872868335
# 序号: 611755, 处理前销量(千克): 11.0, 处理后销量(千克): 3.5797358824078196
# 序号: 621995, 处理前销量(千克): 5.0, 处理后销量(千克): 3.5647151048418437
# 序号: 155060, 处理前销量(千克): 8.776, 处理后销量(千克): 1.2374551792032658
# 序号: 470453, 处理前销量(千克): 3.003, 处理后销量(千克): 0.688111768310432
# 序号: 724406, 处理前销量(千克): 3.741, 处理后销量(千克): 0.6880528428113435
# 序号: 724407, 处理前销量(千克): 4.371, 处理后销量(千克): 0.6879751300162006
# 序号: 144828, 处理前销量(千克): 3.333, 处理后销量(千克): 0.7948889335165177
# 序号: 103869, 处理前销量(千克): 3.182, 处理后销量(千克): 1.2369585034343373
# 序号: 648639, 处理前销量(千克): 5.0, 处理后销量(千克): 3.5618096698314017
# 序号: 155073, 处理前销量(千克): 5.102, 处理后销量(千克): 1.236830354699552
# 序号: 624065, 处理前销量(千克): 5.0, 处理后销量(千克): 3.558898353373571
# 序号: 636362, 处理前销量(千克): 5.0, 处理后销量(千克): 3.5559811435625863
# 序号: 724427, 处理前销量(千克): 3.004, 处理后销量(千克): 0.687881378587666
# 序号: 150989, 处理前销量(千克): 3.17, 处理后销量(千克): 0.687822421768997
# 序号: 617933, 处理前销量(千克): 5.0, 处理后销量(千克): 3.5530580284685835
# 序号: 624077, 处理前销量(千克): 5.0, 处理后销量(千克): 3.5501289961375484
# 序号: 615891, 处理前销量(千克): 5.0, 处理后销量(千克): 3.5471940345912683
# 序号: 617948, 处理前销量(千克): 5.0, 处理后销量(千克): 3.5442531318272827
# 序号: 673255, 处理前销量(千克): 4.295, 处理后销量(千克): 0.6877592379182083
# 序号: 202216, 处理前销量(千克): 7.879, 处理后销量(千克): 1.2365756986417515
# 序号: 202217, 处理前销量(千克): 12.576, 处理后销量(千克): 1.2361380636238732
# 序号: 202218, 处理前销量(千克): 8.03, 处理后销量(千克): 1.2353909387104212
# 序号: 738803, 处理前销量(千克): 3.157, 处理后销量(千克): 0.6876674155747673
# 序号: 611830, 处理前销量(千克): 5.0, 处理后销量(千克): 3.541306275818836
# 序号: 155128, 处理前销量(千克): 11.735, 处理后销量(千克): 1.234943277025002
# 序号: 155129, 处理前销量(千克): 10.0, 处理后销量(千克): 1.2342514825380488
# 序号: 155130, 处理前销量(千克): 8.571, 处理后销量(千克): 1.2336739526581266
# 序号: 607739, 处理前销量(千克): 5.0, 处理后销量(千克): 3.538353454514825
# 序号: 611836, 处理前销量(千克): 10.0, 处理后销量(千克): 3.535394655839754
# 序号: 869889, 处理前销量(千克): 8.0, 处理后销量(千克): 1.391304347826087
# 序号: 728587, 处理前销量(千克): 4.0, 处理后销量(千克): 0.9998557207835369
# 序号: 869902, 处理前销量(千克): 30.0, 处理后销量(千克): 1.3194706994328924
# 序号: 558607, 处理前销量(千克): 9.598, 处理后销量(千克): 0.5525388507604013
# 序号: 611859, 处理前销量(千克): 5.0, 处理后销量(千克): 3.5223084102038023
# 序号: 206356, 处理前销量(千克): 10.404, 处理后销量(千克): 1.2331905341545462
# 序号: 230932, 处理前销量(千克): 7.218, 处理后销量(千克): 0.4366905405440576
# 序号: 626196, 处理前销量(千克): 5.0, 处理后销量(千克): 3.5193171316819476
# 序号: 628244, 处理前销量(千克): 5.0, 处理后销量(千克): 3.516319797940413
# 序号: 628249, 处理前销量(千克): 5.0, 处理后销量(千克): 3.513316396721669
# 序号: 642589, 处理前销量(千克): 5.0, 处理后销量(千克): 3.5103069157433726
# 序号: 628254, 处理前销量(千克): 5.0, 处理后销量(千克): 3.5072913426983185
# 序号: 642590, 处理前销量(千克): 5.0, 处理后销量(千克): 3.5042696652543883
# 序号: 648736, 处理前销量(千克): 5.0, 处理后销量(千克): 3.5012418710544986
# 序号: 611879, 处理前销量(千克): 5.0, 处理后销量(千克): 3.4982079477165517
# 序号: 609836, 处理前销量(千克): 5.0, 处理后销量(千克): 3.4951678828333868
# 序号: 722477, 处理前销量(千克): 3.314, 处理后销量(千克): 0.6876045586934023
# 序号: 607800, 处理前销量(千克): 5.0, 处理后销量(千克): 3.4921216639727257
# 序号: 607801, 处理前销量(千克): 5.0, 处理后销量(千克): 3.489069278677124
# 序号: 626232, 处理前销量(千克): 5.0, 处理后销量(千克): 3.48601071446392
# 序号: 179771, 处理前销量(千克): 11.02, 处理后销量(千克): 1.2325863169015585
# 序号: 87623, 处理前销量(千克): 10.014, 处理后销量(千克): 0.467339154755652
# 序号: 87624, 处理前销量(千克): 10.014, 处理后销量(千克): 0.3826862399380036
# 序号: 56908, 处理前销量(千克): 5.0, 处理后销量(千克): 3.4829459588251828
# 序号: 159309, 处理前销量(千克): 7.347, 处理后销量(千克): 1.231941474782498
# 序号: 317005, 处理前销量(千克): 5.0, 处理后销量(千克): 0.36069375907111756
# 序号: 429648, 处理前销量(千克): 4.523, 处理后销量(千克): 0.39833909569954584
# 序号: 607829, 处理前销量(千克): 5.0, 处理后销量(千克): 3.479874999227663
# 序号: 292445, 处理前销量(千克): 12.487, 处理后销量(千克): 0.46717708598652813
# 序号: 630367, 处理前销量(千克): 9.0, 处理后销量(千克): 0.9986172566371682
# 序号: 642655, 处理前销量(千克): 5.0, 处理后销量(千克): 3.4767978231127388
# 序号: 638562, 处理前销量(千克): 5.0, 处理后销量(千克): 3.473714417896368
# 序号: 618084, 处理前销量(千克): 5.0, 处理后销量(千克): 3.470624770969033
# 序号: 761454, 处理前销量(千克): 3.103, 处理后销量(千克): 0.6875377037757159
# 序号: 648815, 处理前销量(千克): 5.0, 处理后销量(千克): 3.467528869695691
# 序号: 734833, 处理前销量(千克): 3.005, 处理后销量(千克): 0.6874762181629828
# 序号: 642674, 处理前销量(千克): 10.0, 处理后销量(千克): 3.464426701415723
# 序号: 726644, 处理前销量(千克): 3.163, 处理后销量(千克): 1.0053849985884247
# 序号: 618103, 处理前销量(千克): 5.0, 处理后销量(千克): 3.451196795953001
# 序号: 616056, 处理前销量(千克): 5.0, 处理后销量(千克): 3.448061566795012
# 序号: 728695, 处理前销量(千克): 3.651, 处理后销量(千克): 0.6874172255759434
# 序号: 726654, 处理前销量(千克): 3.52, 处理后销量(千克): 1.0050482921275303
# 序号: 624262, 处理前销量(千克): 5.0, 处理后销量(千克): 3.4449199910192934
# 序号: 642697, 处理前销量(千克): 5.0, 处理后销量(千克): 3.4417720557784417
# 序号: 614036, 处理前销量(千克): 5.0, 处理后销量(千克): 3.438617748199045
# 序号: 159381, 处理前销量(千克): 10.714, 处理后销量(千克): 1.2315385851708747
# 序号: 159382, 处理前销量(千克): 7.143, 处理后销量(千克): 1.2309138347811774
# 序号: 628374, 处理前销量(千克): 5.0, 处理后销量(千克): 3.4354570553816344
# 序号: 616089, 处理前销量(千克): 5.0, 处理后销量(千克): 3.432289964400626
# 序号: 726687, 处理前销量(千克): 3.214, 处理后销量(千克): 1.0046558215114452
# 序号: 474784, 处理前销量(千克): 3.071, 处理后销量(千克): 0.6873417875519031
# 序号: 628397, 处理前销量(千克): 5.0, 处理后销量(千克): 3.429116462304271
# 序号: 478903, 处理前销量(千克): 3.054, 处理后销量(千克): 0.6872811115123855
# 序号: 626364, 处理前销量(千克): 17.0, 处理后销量(千克): 3.4259365361146035
# 序号: 595646, 处理前销量(千克): 10.0, 处理后销量(千克): 3.3984586748516774
# 序号: 595647, 处理前销量(千克): 4.0, 处理后销量(千克): 3.385095230873644
# 序号: 614083, 处理前销量(千克): 5.0, 处理后销量(千克): 3.383850484377437
# 序号: 607948, 处理前销量(千克): 5.0, 处理后销量(千克): 3.380578926653505
# 序号: 636621, 处理前销量(千克): 5.0, 处理后销量(千克): 3.377300746343087
# 序号: 822989, 处理前销量(千克): 5.0, 处理后销量(千克): 0.997879666045044
# 序号: 663261, 处理前销量(千克): 5.0, 处理后销量(千克): 3.374015930040138
# 序号: 147167, 处理前销量(千克): 10.0, 处理后销量(千克): 1.2305243179696594
# 序号: 147168, 处理前销量(千克): 13.061, 处理后销量(千克): 1.2299465425261207
# 序号: 605923, 处理前销量(千克): 5.0, 处理后销量(千克): 3.370724464311474
# 序号: 290532, 处理前销量(千克): 3.09, 处理后销量(千克): 1.2291670555411773
# 序号: 646884, 处理前销量(千克): 5.0, 处理后销量(千克): 3.36742633569672
# 序号: 657126, 处理前销量(千克): 5.0, 处理后销量(千克): 3.364121530708252
# 序号: 820969, 处理前销量(千克): 5.0, 处理后销量(千克): 0.9993020512716196
# 序号: 165614, 处理前销量(千克): 3.061, 处理后销量(千克): 1.2290444548728112
# 序号: 618222, 处理前销量(千克): 5.0, 处理后销量(千克): 3.360810035831143
# 序号: 618226, 处理前销量(千克): 5.0, 处理后销量(千克): 3.357491837523109
# 序号: 618228, 处理前销量(千克): 5.0, 处理后销量(千克): 3.3541669222144512
# 序号: 190198, 处理前销量(千克): 3.696, 处理后销量(千克): 0.585221375530073
# 序号: 616182, 处理前销量(千克): 6.98, 处理后销量(千克): 0.554343460934735
# 序号: 607992, 处理前销量(千克): 5.0, 处理后销量(千克): 3.3508352763080027
# 序号: 108286, 处理前销量(千克): 4.0, 处理后销量(千克): 1.0809859154929577
# 序号: 644866, 处理前销量(千克): 5.0, 处理后销量(千克): 3.347496886179072
# 序号: 726786, 处理前销量(千克): 4.0, 处理后销量(千克): 1.0003206978384966
# 序号: 608012, 处理前销量(千克): 10.0, 处理后销量(千克): 3.3441517381753854
# 序号: 724752, 处理前销量(千克): 9.235, 处理后销量(千克): 0.512696279422931
# 序号: 616211, 处理前销量(千克): 5.0, 处理后销量(千克): 3.3306783611271573
# 序号: 618263, 处理前销量(千克): 5.0, 处理后销量(千克): 3.3272991675262005
# 序号: 616224, 处理前销量(千克): 5.0, 处理后销量(千克): 3.3239131334523666
# 序号: 642849, 处理前销量(千克): 5.0, 处理后销量(千克): 3.3205202450585456
# 序号: 612133, 处理前销量(千克): 5.0, 处理后销量(千克): 3.317120488469595
# 序号: 663334, 处理前销量(千克): 5.0, 处理后销量(千克): 3.313713849782287
# 序号: 198444, 处理前销量(千克): 3.14, 处理后销量(千克): 0.6872208666634995
# 序号: 626483, 处理前销量(千克): 5.0, 处理后销量(千克): 3.310300315065247
# 序号: 761656, 处理前销量(千克): 10.0, 处理后销量(千克): 1.0018368853031712
# 序号: 610110, 处理前销量(千克): 5.0, 处理后销量(千克): 3.3068798703589013
# 序号: 646976, 处理前销量(千克): 5.0, 处理后销量(千克): 3.3034525016754173
# 序号: 624452, 处理前销量(千克): 5.0, 处理后销量(千克): 3.3000181949986467
# 序号: 153415, 处理前销量(千克): 13.367, 处理后销量(千克): 1.2289237567870863
# 序号: 646990, 处理前销量(千克): 5.0, 处理后销量(千克): 3.2965769362840693
# 序号: 608080, 处理前销量(千克): 5.0, 处理后销量(千克): 3.2931287114587335
# 序号: 632656, 处理前销量(千克): 5.0, 处理后销量(千克): 3.2896735064212
# 序号: 632657, 处理前销量(千克): 5.0, 处理后销量(千克): 3.2862113070414862
# 序号: 593747, 处理前销量(千克): 6.367, 处理后销量(千克): 0.44665683099431297
# 序号: 606055, 处理前销量(千克): 5.0, 处理后销量(千克): 3.2827420991610032
# 序号: 198509, 处理前销量(千克): 5.707, 处理后销量(千克): 1.2281240416570818
# 序号: 153459, 处理前销量(千克): 3.163, 处理后销量(千克): 1.2278289516611438
# 序号: 153460, 处理前销量(千克): 6.02, 处理后销量(千克): 1.227701453239195
# 序号: 155508, 处理前销量(千克): 11.02, 处理后销量(千克): 1.2273857134482635
# 序号: 614265, 处理前销量(千克): 5.0, 处理后销量(千克): 3.2792658685925034
# 序号: 659331, 处理前销量(千克): 5.0, 处理后销量(千克): 3.275782601120018
# 序号: 661385, 处理前销量(千克): 5.0, 处理后销量(千克): 3.2722922824988037
# 序号: 466826, 处理前销量(千克): 3.06, 处理后销量(千克): 0.6871584311503688
# 序号: 618379, 处理前销量(千克): 5.0, 处理后销量(千克): 3.268794898455279
# 序号: 638860, 处理前销量(千克): 5.0, 处理后销量(千克): 3.26529043468697
# 序号: 186254, 处理前销量(千克): 3.109, 处理后销量(千克): 0.6870980304486036
# 序号: 325519, 处理前销量(千克): 10.0, 处理后销量(千克): 1.0039452390311379
# 序号: 636814, 处理前销量(千克): 5.0, 处理后销量(千克): 3.2617788768624494
# 序号: 767902, 处理前销量(千克): 4.0, 处理后销量(千克): 1.0001282997048193
# 序号: 444320, 处理前销量(千克): 3.079, 处理后销量(千克): 0.6870363809139326
# 序号: 665505, 处理前销量(千克): 5.0, 处理后销量(千克): 3.2582602106212804
# 序号: 126887, 处理前销量(千克): 7.828, 处理后销量(千克): 1.2267405286883117
# 序号: 212905, 处理前销量(千克): 3.047, 处理后销量(千克): 0.5683066880439761
# 序号: 247731, 处理前销量(千克): 3.384, 处理后销量(千克): 1.2263056058083992
# 序号: 503741, 处理前销量(千克): 3.102, 处理后销量(千克): 0.6869754934602204
# 序号: 606142, 处理前销量(千克): 5.0, 处理后销量(千克): 3.2547344215739553
# 序号: 606143, 处理前销量(千克): 5.0, 处理后销量(千克): 3.2512014953018378
# 序号: 643007, 处理前销量(千克): 5.0, 处理后销量(千克): 3.247661417357105
# 序号: 606148, 处理前销量(千克): 5.0, 处理后销量(千克): 3.2441141732626857
# 序号: 178117, 处理前销量(千克): 7.551, 处理后销量(千克): 1.2261634464729008
# 序号: 606153, 处理前销量(千克): 5.0, 处理后销量(千克): 3.2405597485122057
# 序号: 606156, 处理前销量(千克): 5.0, 处理后销量(千克): 3.2369981285699225
# 序号: 634828, 处理前销量(千克): 5.0, 处理后销量(千克): 3.233429298870671
# 序号: 247761, 处理前销量(千克): 3.131, 处理后销量(千克): 1.22574673567085
# 序号: 153557, 处理前销量(千克): 3.98, 处理后销量(千克): 1.2256212083771139
# 序号: 153558, 处理前销量(千克): 4.082, 处理后销量(千克): 1.2254397365895515
# 序号: 649175, 处理前销量(千克): 5.0, 处理后销量(千克): 3.229853244819802
# 序号: 180187, 处理前销量(千克): 3.096, 处理后销量(千克): 0.6869140189914272
# 序号: 636891, 处理前销量(千克): 5.0, 处理后销量(千克): 3.2262699517931215
# 序号: 634847, 处理前销量(千克): 5.0, 处理后销量(千克): 3.222679405136833
# 序号: 643039, 处理前销量(千克): 5.0, 处理后销量(千克): 3.2190815901674736
# 序号: 606184, 处理前销量(千克): 5.0, 处理后销量(千克): 3.2154764921718617
# 序号: 649201, 处理前销量(千克): 5.0, 处理后销量(千克): 3.211864096407027
# 序号: 630774, 处理前销量(千克): 5.0, 处理后销量(千克): 3.2082443881001588
# 序号: 643063, 处理前销量(千克): 5.0, 处理后销量(千克): 3.2046173524485395
# 序号: 630776, 处理前销量(千克): 5.0, 处理后销量(千克): 3.200982974619488
# 序号: 718839, 处理前销量(千克): 3.062, 处理后销量(千克): 0.6868526956878506
# 序号: 641020, 处理前销量(千克): 5.0, 处理后销量(千克): 3.197341239750297
# 627

# %%
merged_df.head()
# Out:
#    序号        销售日期    扫码销售时间             单品编码  销量(千克)  销售单价(元/千克)  销售类型  \
# 0   1  2020-07-01  0.385508  102900005117056   0.396         7.6     1
# 1   2  2020-07-01  0.387121  102900005115960   0.849         3.2     1
# 2   3  2020-07-01  0.387198  102900005117056   0.409         7.6     1
# 3   4  2020-07-01  0.388720  102900005115823   0.421        10.0     1
# 4   5  2020-07-01  0.389163  102900005115908   0.539         8.0     1
#
#    是否打折销售     单品名称 分类名称  批发价格(元/千克)  星期  年中进度                      周       月份  \
# 0       0  泡泡椒(精品)  辣椒类        4.32   3   0.5  2020-06-29/2020-07-05  2020-07
# 1       0      大白菜  花叶类        2.10   3   0.5  2020-06-29/2020-07-05  2020-07
# 2       0  泡泡椒(精品)  辣椒类        4.32   3   0.5  2020-06-29/2020-07-05  2020-07
# 3       0      上海青  花叶类        7.03   3   0.5  2020-06-29/2020-07-05  2020-07
# 4       0       菜心  花叶类        4.60   3   0.5  2020-06-29/2020-07-05  2020-07
#
#        季度    交易金额       利润
# 0  2020Q3  3.0096  1.29888
# 1  2020Q3  2.7168  0.93390
# 2  2020Q3  3.1084  1.34152
# 3  2020Q3  4.2100  1.25037
# 4  2020Q3  4.3120  1.83260

# %%
merged_df.describe()
# Out:
#                   序号         扫码销售时间          单品编码         销量(千克)  \
# count  878503.000000  878503.000000  8.785030e+05  878503.000000
# mean   439252.000000       0.621333  1.030313e+14       0.533810
# std    253602.116104       0.152056  7.174368e+11       0.336168
# min         1.000000       0.343202  1.029000e+14      -9.082000
# 25%    219626.500000       0.467446  1.029000e+14       0.290000
# 50%    439252.000000       0.642595  1.029000e+14       0.435000
# 75%    658877.500000       0.752034  1.029000e+14       0.741000
# max    878503.000000       0.966528  1.069740e+14       4.878049
#
#           销售单价(元/千克)           销售类型         是否打折销售     批发价格(元/千克)  \
# count  878503.000000  878503.000000  878503.000000  878503.000000
# mean        8.917144       0.998950       0.053917       5.663150
# std         6.311265       0.045803       0.225853       4.229638
# min         0.100000      -1.000000       0.000000       0.010000
# 25%         4.900000       1.000000       0.000000       3.000000
# 50%         7.900000       1.000000       0.000000       4.690000
# 75%        10.800000       1.000000       0.000000       7.010000
# max       119.900000       1.000000       1.000000     141.000000
#
#                   星期           年中进度           交易金额             利润
# count  878503.000000  878503.000000  878503.000000  878503.000000
# mean        4.268100       0.505362       3.835805       1.415649
# std         2.041563       0.287668       2.813984       1.249791
# min         1.000000       0.002740    -100.000000    -161.900000
# 25%         2.000000       0.246575       2.210000       0.733405
# 50%         4.000000       0.538251       3.332000       1.195600
# 75%         6.000000       0.745902       4.791600       1.859550
# max         7.000000       1.000000     944.000000     420.800000

# %%
# 将合并后的DataFrame保存为新的Excel文件
merged_df.to_excel("/home/aistudio/data/data237885/附件2(处理后).xlsx", index=False)

# %%
# 检查“销售类型”是“销售”，但“销量(千克)”不是正数的情况
mask1 = (merged_df['销售类型'] == '销售') & (merged_df['销量(千克)'] <= 0)
# 检查“销售类型”是“退货”，但“销量(千克)”不是负数的情况
mask2 = (merged_df['销售类型'] == '退货') & (merged_df['销量(千克)'] >= 0)

# 将不符合条件的行选出来
invalid_rows1 = merged_df[mask1]
invalid_rows2 = merged_df[mask2]

if len(invalid_rows1) > 0:
    print("以下行的‘销售类型’是‘销售’，但‘销量(千克)’不是正数：")
    print(invalid_rows1)
if len(invalid_rows2) > 0:
    print("以下行的‘销售类型’是‘退货’，但‘销量(千克)’不是负数：")
    print(invalid_rows2)

if len(invalid_rows1) == 0 and len(invalid_rows2) == 0:
    print("所有数据都满足条件。")
# Out:
# 所有数据都满足条件。

# %%
# 转换'销售日期'列为日期格式，并提取月份信息
merged_df['销售日期'] = pd.to_datetime(merged_df['销售日期'])
merged_df['月份'] = merged_df['销售日期'].dt.to_period('M')  # 将日期转换为月份

# 按照月份和分类名称分组，然后计算每组的“销量(千克)”和“利润”的总和
grouped_df = merged_df.groupby(['月份', '分类名称']).agg({'销量(千克)': 'sum', '利润': 'sum'}).reset_index()

# 转换为宽格式
pivot_df = grouped_df.pivot(index='月份', columns='分类名称', values=['销量(千克)', '利润'])

# 重命名列名以便于理解
pivot_df.columns = [f"{col[1]}{col[0]}" for col in pivot_df.columns]

# 将月份列的数据类型转换为字符串，并格式化为"YYYY-MM"格式
pivot_df.index = pivot_df.index.strftime('%Y-%m')

# 保存为新的Excel文件
pivot_df.to_excel("/home/aistudio/data/data237885/每月各品类销量及利润分析.xlsx")

# %%
# 按照销售日期、星期和分类名称分组，然后计算每组的“销量(千克)”和“利润”的总和
grouped_df = merged_df.groupby(['销售日期', '星期', '分类名称']).agg({'销量(千克)': 'sum', '利润': 'sum'}).reset_index()

# 转换为宽格式
pivot_df = grouped_df.pivot(index=['销售日期', '星期'], columns='分类名称', values=['销量(千克)', '利润'])

# 重命名列名以便于理解
pivot_df.columns = [f"{col[1]}_{col[0]}" for col in pivot_df.columns]

# 由于索引现在是多层次的（销售日期和星期），我们只将销售日期列的数据类型转换为字符串，并格式化为"YYYY-MM-DD"格式
pivot_df.index = pd.MultiIndex.from_tuples([(idx[0].strftime('%Y-%m-%d'), idx[1]) for idx in pivot_df.index])

# 保存为新的Excel文件
pivot_df.to_excel("/home/aistudio/data/data237885/每日各品类销量及利润分析.xlsx")

# %%
# 创建一个日期范围从2020-07-01到2023-06-30
all_dates = pd.date_range(start='2020-07-01', end='2023-06-30')

# 查找在'销售日期'列中存在的日期
existing_dates = pd.to_datetime(merged_df['销售日期'].unique())

# 使用Pandas的Index差集功能来找到缺失的日期
missing_dates = all_dates.difference(existing_dates)

# 打印或输出缺失的日期
print("缺失的日期如下：")
print(missing_dates)
# Out:
# 缺失的日期如下：
# DatetimeIndex(['2021-02-11', '2021-02-12', '2022-01-31', '2022-11-02',
#                '2022-11-04', '2022-11-30', '2022-12-01', '2022-12-02',
#                '2022-12-03', '2023-01-21'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## 一键快速预览数据
#
# import numpy as np
# from ydata_profiling import ProfileReport
#
# #创建数据分析报告
# profile = ProfileReport(merged_df, title='Your Data Analysis Report', explorative=True)
#
# #保存报告为HTML文件
# profile.to_file("/home/aistudio/data/data237885/merged_ydata_report.html")
#
# #显示报告（适用于Jupyter Notebook）
# profile.to_notebook_iframe()

# %%
from datetime import datetime

# 定义数据中最早和最晚的两个日期字符串
date_str1 = '2020-07-01 00:00:00'
date_str2 = '2023-06-30 00:00:00'

# 将日期字符串转换为 datetime 对象
date1 = datetime.strptime(date_str1, '%Y-%m-%d %H:%M:%S')
date2 = datetime.strptime(date_str2, '%Y-%m-%d %H:%M:%S')

# 计算两个日期之间的天数差
delta = date2 - date1

# 输出天数
print(f"间隔天数: {delta.days}（天）")
# Out:
# 间隔天数: 1094（天）

# %%
temp_merged_df = merged_df.copy()

print(temp_merged_df.shape)
# Out:
# (878503, 18)

# %%
# Step 1: 创建 temp_merged_df 作为 merged_df 的副本
temp_merged_df = merged_df.copy()

# Step 2: 按照“销售日期”和“单品名称”进行分组，计算每天各单品的总“销量(千克)”
grouped_df = temp_merged_df.groupby(['销售日期', '单品名称'])['销量(千克)'].sum().reset_index()

# Step 3: 使用 df1 中的全部单品名称，确保所有单品都在结果中出现
# 创建一个唯一的销售日期列表和单品名称列表
unique_dates = temp_merged_df['销售日期'].unique()
unique_products = df1['单品名称'].unique()

# 创建一个全排列的 DataFrame，其中包含所有可能的“销售日期”和“单品名称”组合
import itertools
all_combinations = pd.DataFrame(list(itertools.product(unique_dates, unique_products)), columns=['销售日期', '单品名称'])

# 将全排列的 DataFrame 与 grouped_df 合并，以获取每个单品每天的销量（如果没有记录，则为 0）
final_df = pd.merge(all_combinations, grouped_df, on=['销售日期', '单品名称'], how='left').fillna(0)

# 添加“分类名称”列
final_df = pd.merge(final_df, df1[['单品名称', '分类名称']], on='单品名称', how='left')

output_path = '/home/aistudio/data/data237885/每日各单品总销量情况.xlsx'
final_df.to_excel(output_path, index=False)
